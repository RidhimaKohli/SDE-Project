# %%
R.Version()
# Out:
# $platform
# [1] "x86_64-pc-linux-gnu"
#
# $arch
# [1] "x86_64"
#
# $os
# [1] "linux-gnu"
#
# $system
# [1] "x86_64, linux-gnu"
#
# $status
# [1] ""
#
# $major
# [1] "4"
#
# $minor
# [1] "1.3"
#
# $year
# [1] "2022"
#
# $month
# [1] "03"
#
# $day
# [1] "10"
#
# $`svn rev`
# [1] "81868"
#
# $language
# [1] "R"
#
# $version.string
# [1] "R version 4.1.3 (2022-03-10)"
#
# $nickname
# [1] "One Push-Up"

# %%
### uploading data /content/GUI-issue-metrics.csv

configuration_metrics <- read.csv(file="/content/configuration-issue-metrics.csv", header=TRUE, sep=";")
network_metrics <- read.csv(file="/content/network-issue-metrics.csv", header=TRUE, sep=";")
database_metrics <- read.csv(file="/content/database-issue-metrics.csv", header=TRUE, sep=";")
gui_metrics <- read.csv(file="/content/GUI-issue-metrics.csv", header=TRUE, sep=";")
performance_metrics <- read.csv(file="/content/performance-issue-metrics.csv", header=TRUE, sep=";")
deprecation_metrics <- read.csv(file="/content/deprecation-issue-metrics.csv", header=TRUE, sep=";")
security_metrics <- read.csv(file="/content/security-issue-metrics.csv", header=TRUE, sep=";")
program_anomaly_metrics <- read.csv(file="/content/programAnomaly-issue-metrics.csv", header=TRUE, sep=";")
test_metrics <- read.csv(file="/content/test-issue-metrics.csv", header=TRUE, sep=";")

 

boxplot(configuration_metrics$DBR...Delay.Before.Response, network_metrics$DBR...Delay.Before.Response, database_metrics$DBR...Delay.Before.Response, gui_metrics$DBR...Delay.Before.Response, performance_metrics$DBR...Delay.Before.Response, deprecation_metrics$DBR...Delay.Before.Response, security_metrics$DBR...Delay.Before.Response, program_anomaly_metrics$DBR...Delay.Before.Response, test_metrics$DBR...Delay.Before.Response, ylab="Delay Before Response", names=c("conf.-issue", "network-issue", "db-issue", "gui-issue", "perf.-issue", "perm.-depr.-issue", "sec.-issue", "program-issue", "test-issue"), col=c("gray", "royalblue2", "palevioletred1", "aliceblue", "chocolate", "brown1", "burlywood", "red", "cadetblue1"))

means <- c(mean(configuration_metrics$DBR...Delay.Before.Response), mean(network_metrics$DBR...Delay.Before.Response), mean(database_metrics$DBR...Delay.Before.Response), mean(gui_metrics$DBR...Delay.Before.Response), mean(performance_metrics$DBR...Delay.Before.Response), mean(deprecation_metrics$DBR...Delay.Before.Response), mean(security_metrics$DBR...Delay.Before.Response), mean(program_anomaly_metrics$DBR...Delay.Before.Response), mean(test_metrics$DBR...Delay.Before.Response))

points(means,col="black", pch=16)




boxplot(configuration_metrics$DBA...Delay.Before.Assigned, network_metrics$DBA...Delay.Before.Assigned, database_metrics$DBA...Delay.Before.Assigned, gui_metrics$DBA...Delay.Before.Assigned, performance_metrics$DBA...Delay.Before.Assigned, deprecation_metrics$DBA...Delay.Before.Assigned, security_metrics$DBA...Delay.Before.Assigned, program_anomaly_metrics$DBA...Delay.Before.Assigned, test_metrics$DBA...Delay.Before.Assigned, ylab="Delay Before Assigned", names=c("conf.-issue", "network-issue", "db-issue", "gui-issue", "perf.-issue", "perm.-depr.-issue", "sec.-issue", "program-issue", "test-issue"), col=c("gray", "royalblue2", "palevioletred1", "aliceblue", "chocolate", "brown1", "burlywood", "red", "cadetblue1"))

means <- c(mean(configuration_metrics$DBA...Delay.Before.Assigned), mean(network_metrics$DBA...Delay.Before.Assigned), mean(database_metrics$DBA...Delay.Before.Assigned), mean(gui_metrics$DBA...Delay.Before.Assigned), mean(performance_metrics$DBA...Delay.Before.Assigned), mean(deprecation_metrics$DBA...Delay.Before.Assigned), mean(security_metrics$DBA...Delay.Before.Assigned), mean(program_anomaly_metrics$DBA...Delay.Before.Assigned), mean(test_metrics$DBA...Delay.Before.Assigned))

points(means,col="black", pch=16)





boxplot(configuration_metrics$DBC...Delay.Before.Change, network_metrics$DBC...Delay.Before.Change, database_metrics$DBC...Delay.Before.Change, gui_metrics$DBC...Delay.Before.Change, performance_metrics$DBC...Delay.Before.Change, deprecation_metrics$DBC...Delay.Before.Change, security_metrics$DBC...Delay.Before.Change, program_anomaly_metrics$DBC...Delay.Before.Change, test_metrics$DBC...Delay.Before.Change, ylab="Delay Before Change", names=c("conf.-issue", "network-issue", "db-issue", "gui-issue", "perf.-issue", "perm.-depr.-issue", "sec.-issue", "program-issue", "test-issue"), col=c("gray", "royalblue2", "palevioletred1", "aliceblue", "chocolate", "brown1", "burlywood", "red", "cadetblue1"))

means <- c(mean(configuration_metrics$DBC...Delay.Before.Change), mean(network_metrics$DBC...Delay.Before.Change), mean(database_metrics$DBC...Delay.Before.Change), mean(gui_metrics$DBC...Delay.Before.Change), mean(performance_metrics$DBC...Delay.Before.Change), mean(deprecation_metrics$DBC...Delay.Before.Change), mean(security_metrics$DBC...Delay.Before.Change), mean(program_anomaly_metrics$DBC...Delay.Before.Change), mean(test_metrics$DBC...Delay.Before.Change))

points(means,col="black", pch=16)



 

boxplot(configuration_metrics$DBF...Duration.of.Bug.Fixing, network_metrics$DBF...Duration.of.Bug.Fixing, database_metrics$DBF...Duration.of.Bug.Fixing, gui_metrics$DBF...Duration.of.Bug.Fixing, performance_metrics$DBF...Duration.of.Bug.Fixing, deprecation_metrics$DBF...Duration.of.Bug.Fixing, security_metrics$DBF...Duration.of.Bug.Fixing, program_anomaly_metrics$DBF...Duration.of.Bug.Fixing, test_metrics$DBF...Duration.of.Bug.Fixing, ylab="Duration of Bug Fixing", names=c("conf.-issue", "network-issue", "db-issue", "gui-issue", "perf.-issue", "perm.-depr.-issue", "sec.-issue", "program-issue", "test-issue"), col=c("gray", "royalblue2", "palevioletred1", "aliceblue", "chocolate", "brown1", "burlywood", "red", "cadetblue1"))

means <- c(mean(configuration_metrics$DBF...Duration.of.Bug.Fixing), mean(network_metrics$DBF...Duration.of.Bug.Fixing), mean(database_metrics$DBF...Duration.of.Bug.Fixing), mean(gui_metrics$DBF...Duration.of.Bug.Fixing), mean(performance_metrics$DBF...Duration.of.Bug.Fixing), mean(deprecation_metrics$DBF...Duration.of.Bug.Fixing), mean(security_metrics$DBF...Duration.of.Bug.Fixing), mean(program_anomaly_metrics$DBF...Duration.of.Bug.Fixing), mean(test_metrics$DBF...Duration.of.Bug.Fixing))

points(means,col="black", pch=16)





boxplot(configuration_metrics$DAC...Delay.After.Change, network_metrics$DAC...Delay.After.Change, database_metrics$DAC...Delay.After.Change, gui_metrics$DAC...Delay.After.Change, performance_metrics$DAC...Delay.After.Change, deprecation_metrics$DAC...Delay.After.Change, security_metrics$DAC...Delay.After.Change, program_anomaly_metrics$DAC...Delay.After.Change, test_metrics$DAC...Delay.After.Change, ylab="Delay After Change", names=c("conf.-issue", "network-issue", "db-issue", "gui-issue", "perf.-issue", "perm.-depr.-issue", "sec.-issue", "program-issue", "test-issue"), col=c("gray", "royalblue2", "palevioletred1", "aliceblue", "chocolate", "brown1", "burlywood", "red", "cadetblue1"))

means <- c(mean(configuration_metrics$DAC...Delay.After.Change), mean(network_metrics$DAC...Delay.After.Change), mean(database_metrics$DAC...Delay.After.Change), mean(gui_metrics$DAC...Delay.After.Change), mean(performance_metrics$DAC...Delay.After.Change), mean(deprecation_metrics$DAC...Delay.After.Change), mean(security_metrics$DAC...Delay.After.Change), mean(program_anomaly_metrics$DAC...Delay.After.Change), mean(test_metrics$DAC...Delay.After.Change))

points(means,col="black", pch=16)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
